# %% [markdown]
# dependencies and sample folder path

# %%
import os
import numpy as np
import cv2
from PIL import Image

imgpth = "tmp/imgadd_th.png"

img = cv2.imread(imgpth, cv2.IMREAD_UNCHANGED)
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=L size=1280x960>

# %%
num_labels, labels, stats, centroid = cv2.connectedComponentsWithStats(img, 8)

# %%
num_labels
# Out:
# 2

# %%
stats[0,-1]
# Out:
# 911442

# %%
labels.shape
# Out:
# (960, 1280)
